# %% [markdown]
# # **Mount the google drive to google colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import Required Module**

# %%
import tensorflow as tf
from keras.callbacks import EarlyStopping
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Conv2D
from keras.models import Sequential
from IPython.display import display
from keras.regularizers import l2
from PIL import Image
from tensorflow.keras.losses import categorical_crossentropy
from keras.layers import Dropout
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
import numpy as np
import cv2
from keras.optimizers import SGD
from keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %% [markdown]
# # **Read the data from csv into dataframe**
#
# 1.   Remove the age and gender column from the dataset

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/age_gender.csv")
df.drop(columns= ['img_name','age','gender'], axis=1, inplace= True)
df['pixels']=df['pixels'].apply(lambda x:  np.array(x.split(), dtype="float32"))

# %%
X = np.array(df['pixels'].tolist())
y = df['ethnicity']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=37)

# %% [markdown]
# # **# Visualize the Ethnicity distribution in the data**

# %%
import seaborn as sns
sns.barplot(y=list(df['ethnicity'].value_counts().values),x= list(df['ethnicity'].value_counts().index))

# %% [markdown]
# Distric=bution of data in the sample

# %%
from pandas import read_csv
from collections import Counter
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder

y_en = LabelEncoder().fit_transform(y_train)
# summarize distribution
counter = Counter(y_en)
for k,v in counter.items():
	per = v / len(y_en) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
pyplot.bar(counter.keys(), counter.values())
pyplot.show()
# Out:
# Class=1, n=3624 (19.110%)
# Class=0, n=8056 (42.480%)
# Class=2, n=2723 (14.359%)
# Class=3, n=3185 (16.795%)
# Class=4, n=1376 (7.256%)

# %% [markdown]
# should we sampe before split or after split?

# %%
from pandas import read_csv
from imblearn.over_sampling import SMOTE
from collections import Counter
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder

oversample = SMOTE()
X_, y_ = oversample.fit_resample(X_train, y_train)
# summarize distribution
counter = Counter(y_)
for k,v in counter.items():
	per = v / len(y_) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
pyplot.bar(counter.keys(), counter.values())
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Class=1, n=8056 (20.000%)
# Class=0, n=8056 (20.000%)
# Class=2, n=8056 (20.000%)
# Class=3, n=8056 (20.000%)
# Class=4, n=8056 (20.000%)

# %%
X_ = X_.reshape(X_.shape[0],48,48,1)
print(y_.shape)

Y_ =  to_categorical(y_)
# Out:
# (40280,)

# %%
from keras.regularizers import l2
model4=Sequential()
model4.add(Conv2D(36,(3,3),input_shape=(48,48,1),padding='same'))
model4.add(BatchNormalization())
model4.add(Activation('relu'))
model4.add(MaxPool2D(2,2))

model4.add(Conv2D(64,(3,3)))
model4.add(BatchNormalization())
model4.add(Activation('relu'))
model4.add(MaxPool2D(2,2))


model4.add(Conv2D(128,(3,3)))
model4.add(BatchNormalization())
model4.add(Activation('relu'))
model4.add(MaxPool2D(2,2))

model4.add(Flatten())



model4.add(Dense(1024, activation='relu'))
model4.add(Dropout(0.2))
model4.add(Dense(512, activation='relu'))
model4.add(Dropout(0.3))
model4.add(Dense(5,activation='softmax'))

opt =Adam(lr=0.0001,decay=0.000001)
#opt =Adam(lr=0.001)
model4.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 36)        360
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 36)        144
# _________________________________________________________________
# activation (Activation)      (None, 48, 48, 36)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 36)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 64)        20800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 22, 22, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 22, 22, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 128)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 2,721,469
# Trainable params: 2,721,013
# Non-trainable params: 456
# _________________________________________________________________

# %% [markdown]
# # ***Model  with batch normalization with no balancing of the data ***

# %%
# fit model
history4 = model4.fit(X_,Y_ ,epochs=500,validation_split=0.2,validation_data=(X_test,y_test),batch_size =32)
# Out:
# Epoch 1/500
# 1007/1007 [==============================] - 21s 5ms/step - loss: 1.0493 - accuracy: 0.6117 - val_loss: 2.2366 - val_accuracy: 0.1610
# Epoch 2/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.6150 - accuracy: 0.7931 - val_loss: 1.9211 - val_accuracy: 0.1678
# Epoch 3/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.4840 - accuracy: 0.8403 - val_loss: 1.6990 - val_accuracy: 0.2301
# Epoch 4/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.4138 - accuracy: 0.8581 - val_loss: 1.8085 - val_accuracy: 0.2329
# Epoch 5/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.3523 - accuracy: 0.8820 - val_loss: 1.5643 - val_accuracy: 0.2681
# Epoch 6/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.2910 - accuracy: 0.9024 - val_loss: 1.2757 - val_accuracy: 0.4242
# Epoch 7/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.2464 - accuracy: 0.9162 - val_loss: 1.4624 - val_accuracy: 0.3397
# Epoch 8/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.2083 - accuracy: 0.9291 - val_loss: 1.2747 - val_accuracy: 0.4285
# Epoch 9/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.1856 - accuracy: 0.9358 - val_loss: 1.3454 - val_accuracy: 0.4603
# Epoch 10/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.1624 - accuracy: 0.9424 - val_loss: 1.0276 - val_accuracy: 0.5523
# Epoch 11/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.1331 - accuracy: 0.9531 - val_loss: 0.9410 - val_accuracy: 0.5911
# Epoch 12/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.1175 - accuracy: 0.9581 - val_loss: 0.5156 - val_accuracy: 0.8101
# Epoch 13/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.1037 - accuracy: 0.9633 - val_loss: 0.4982 - val_accuracy: 0.8091
# Epoch 14/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0961 - accuracy: 0.9652 - val_loss: 0.9311 - val_accuracy: 0.6147
# Epoch 15/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0873 - accuracy: 0.9697 - val_loss: 1.4357 - val_accuracy: 0.5109
# Epoch 16/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0773 - accuracy: 0.9738 - val_loss: 0.4954 - val_accuracy: 0.8153
# Epoch 17/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0700 - accuracy: 0.9750 - val_loss: 0.5435 - val_accuracy: 0.8119
# Epoch 18/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0557 - accuracy: 0.9796 - val_loss: 0.6902 - val_accuracy: 0.7515
# Epoch 19/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0612 - accuracy: 0.9783 - val_loss: 0.7016 - val_accuracy: 0.7511
# Epoch 20/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0450 - accuracy: 0.9849 - val_loss: 0.5014 - val_accuracy: 0.8199
# Epoch 21/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0499 - accuracy: 0.9821 - val_loss: 0.7596 - val_accuracy: 0.7422
# Epoch 22/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0495 - accuracy: 0.9830 - val_loss: 0.4732 - val_accuracy: 0.8391
# Epoch 23/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.5180 - val_accuracy: 0.8358
# Epoch 24/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0422 - accuracy: 0.9853 - val_loss: 0.7832 - val_accuracy: 0.7470
# Epoch 25/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0424 - accuracy: 0.9860 - val_loss: 0.5375 - val_accuracy: 0.8231
# Epoch 26/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0349 - accuracy: 0.9884 - val_loss: 0.6110 - val_accuracy: 0.8256
# Epoch 27/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0375 - accuracy: 0.9876 - val_loss: 1.1060 - val_accuracy: 0.6861
# Epoch 28/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.4848 - val_accuracy: 0.8509
# Epoch 29/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.9900 - val_loss: 0.3562 - val_accuracy: 0.8880
# Epoch 30/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0299 - accuracy: 0.9901 - val_loss: 0.3541 - val_accuracy: 0.8970
# Epoch 31/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0300 - accuracy: 0.9904 - val_loss: 0.5100 - val_accuracy: 0.8363
# Epoch 32/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 0.3030 - val_accuracy: 0.9014
# Epoch 33/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0336 - accuracy: 0.9883 - val_loss: 0.7020 - val_accuracy: 0.8019
# Epoch 34/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.2159 - val_accuracy: 0.9363
# Epoch 35/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.6064 - val_accuracy: 0.8215
# Epoch 36/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0256 - accuracy: 0.9922 - val_loss: 0.3521 - val_accuracy: 0.8904
# Epoch 37/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0283 - accuracy: 0.9911 - val_loss: 0.3274 - val_accuracy: 0.8964
# Epoch 38/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0260 - accuracy: 0.9915 - val_loss: 0.5541 - val_accuracy: 0.8373
# Epoch 39/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0187 - accuracy: 0.9929 - val_loss: 0.9053 - val_accuracy: 0.7599
# Epoch 40/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0305 - accuracy: 0.9899 - val_loss: 1.0489 - val_accuracy: 0.7121
# Epoch 41/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0227 - accuracy: 0.9926 - val_loss: 0.3645 - val_accuracy: 0.8921
# Epoch 42/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 1.0012 - val_accuracy: 0.7212
# Epoch 43/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0259 - accuracy: 0.9906 - val_loss: 0.6506 - val_accuracy: 0.8263
# Epoch 44/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.2737 - val_accuracy: 0.9178
# Epoch 45/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0200 - accuracy: 0.9925 - val_loss: 0.3187 - val_accuracy: 0.9167
# Epoch 46/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0199 - accuracy: 0.9926 - val_loss: 0.6193 - val_accuracy: 0.8436
# Epoch 47/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0216 - accuracy: 0.9918 - val_loss: 0.3830 - val_accuracy: 0.9004
# Epoch 48/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0228 - accuracy: 0.9922 - val_loss: 0.5518 - val_accuracy: 0.8472
# Epoch 49/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0140 - accuracy: 0.9947 - val_loss: 0.7228 - val_accuracy: 0.8235
# Epoch 50/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0256 - accuracy: 0.9901 - val_loss: 0.3875 - val_accuracy: 0.8960
# Epoch 51/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0133 - accuracy: 0.9946 - val_loss: 0.4666 - val_accuracy: 0.8873
# Epoch 52/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 0.3431 - val_accuracy: 0.9009
# Epoch 53/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0160 - accuracy: 0.9936 - val_loss: 0.6306 - val_accuracy: 0.8466
# Epoch 54/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.3876 - val_accuracy: 0.8932
# Epoch 55/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.
500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 0.4182 - val_accuracy: 0.8939
# Epoch 88/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0093 - accuracy: 0.9963 - val_loss: 0.4646 - val_accuracy: 0.8863
# Epoch 89/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.3694 - val_accuracy: 0.8975
# Epoch 90/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0124 - accuracy: 0.9956 - val_loss: 0.6755 - val_accuracy: 0.8551
# Epoch 91/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0084 - accuracy: 0.9967 - val_loss: 0.7339 - val_accuracy: 0.8469
# Epoch 92/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0137 - accuracy: 0.9938 - val_loss: 1.0103 - val_accuracy: 0.7855
# Epoch 93/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0108 - accuracy: 0.9957 - val_loss: 0.5355 - val_accuracy: 0.8735
# Epoch 94/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0073 - accuracy: 0.9967 - val_loss: 0.6456 - val_accuracy: 0.8563
# Epoch 95/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 0.7893 - val_accuracy: 0.8306
# Epoch 96/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0111 - accuracy: 0.9953 - val_loss: 0.3973 - val_accuracy: 0.9070
# Epoch 97/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0078 - accuracy: 0.9962 - val_loss: 0.3532 - val_accuracy: 0.9070
# Epoch 98/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0093 - accuracy: 0.9963 - val_loss: 0.3336 - val_accuracy: 0.9065
# Epoch 99/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 1.0333 - val_accuracy: 0.7679
# Epoch 100/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0117 - accuracy: 0.9950 - val_loss: 0.3721 - val_accuracy: 0.9073
# Epoch 101/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0071 - accuracy: 0.9969 - val_loss: 0.4280 - val_accuracy: 0.8941
# Epoch 102/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.9295 - val_accuracy: 0.8011
# Epoch 103/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 0.3133 - val_accuracy: 0.9263
# Epoch 104/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0137 - accuracy: 0.9943 - val_loss: 0.5227 - val_accuracy: 0.8810
# Epoch 105/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 1.0524 - val_accuracy: 0.7644
# Epoch 106/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.5750 - val_accuracy: 0.8741
# Epoch 107/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0093 - accuracy: 0.9963 - val_loss: 0.4470 - val_accuracy: 0.8964
# Epoch 108/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0109 - accuracy: 0.9959 - val_loss: 0.4296 - val_accuracy: 0.9044
# Epoch 109/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0121 - accuracy: 0.9953 - val_loss: 0.4101 - val_accuracy: 0.9000
# Epoch 110/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.5207 - val_accuracy: 0.8824
# Epoch 111/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.4896 - val_accuracy: 0.8934
# Epoch 112/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0087 - accuracy: 0.9961 - val_loss: 0.5189 - val_accuracy: 0.8802
# Epoch 113/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0074 - accuracy: 0.9967 - val_loss: 0.5509 - val_accuracy: 0.8801
# Epoch 114/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.1928 - val_accuracy: 0.9549
# Epoch 115/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.8339 - val_accuracy: 0.8235
# Epoch 116/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 0.4088 - val_accuracy: 0.9062
# Epoch 117/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0102 - accuracy: 0.9960 - val_loss: 0.4402 - val_accuracy: 0.8965
# Epoch 118/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.3681 - val_accuracy: 0.9059
# Epoch 119/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 1.0078 - val_accuracy: 0.8251
# Epoch 120/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.3858 - val_accuracy: 0.9115
# Epoch 121/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.5512 - val_accuracy: 0.8836
# Epoch 122/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0079 - accuracy: 0.9968 - val_loss: 0.4405 - val_accuracy: 0.9078
# Epoch 123/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0090 - accuracy: 0.9959 - val_loss: 0.3210 - val_accuracy: 0.9220
# Epoch 124/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0079 - accuracy: 0.9961 - val_loss: 0.4384 - val_accuracy: 0.8940
# Epoch 125/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.6382 - val_accuracy: 0.8818
# Epoch 126/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9958 - val_loss: 0.2880 - val_accuracy: 0.9266
# Epoch 127/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.2941 - val_accuracy: 0.9256
# Epoch 128/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0108 - accuracy: 0.9955 - val_loss: 0.6624 - val_accuracy: 0.8535
# Epoch 129/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0099 - accuracy: 0.9954 - val_loss: 0.3677 - val_accuracy: 0.9187
# Epoch 130/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.5869 - val_accuracy: 0.8911
# Epoch 131/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.2299 - val_accuracy: 0.9477
# Epoch 132/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0080 - accuracy: 0.9965 - val_loss: 0.7965 - val_accuracy: 0.8339
# Epoch 133/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9961 - val_loss: 0.6917 - val_accuracy: 0.8426
# Epoch 134/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.8417 - val_accuracy: 0.8350
# Epoch 135/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0077 - accuracy: 0.9966 - val_loss: 0.6284 - val_accuracy: 0.8597
# Epoch 136/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.3602 - val_accuracy: 0.9204
# Epoch 137/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.7863 - val_accuracy: 0.8400
# Epoch 138/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0102 - accuracy: 0.9962 - val_loss: 0.4427 - val_accuracy: 0.9038
# Epoch 139/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0080 - accuracy: 0.9964 - val_loss: 0.4784 - val_accuracy: 0.8952
# Epoch 140/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.5780 - val_accuracy: 0.8672
# Epoch 141/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 0.4483 - val_accuracy: 0.8936
# Epoch 142/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0078 - accuracy: 0.9968 - val_loss: 0.7715 - val_accuracy: 0.8425
# Epoch 143/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.9452 - val_accuracy: 0.8088
# Epoch 144/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 1.2300 - val_accuracy: 0.7588
# Epoch 145/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.4642 - val_accuracy: 0.8918
# Epoch 146/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0077 - accuracy: 0.9967 - val_loss: 0.4485 - val_accuracy: 0.9032
# Epoch 147/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0085 - accuracy: 0.9962 - val_loss: 0.7109 - val_accuracy: 0.8563
# Epoch 148/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 0.5384 - val_accuracy: 0.8807
# Epoch 149/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.6612 - val_accuracy: 0.8592
# Epoch 150/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0082 - accuracy: 0.9968 - val_loss: 0.9861 - val_accuracy: 0.8159
# Epoch 151/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.
500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0047 - accuracy: 0.9973 - val_loss: 0.3182 - val_accuracy: 0.9297
# Epoch 184/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0089 - accuracy: 0.9963 - val_loss: 0.2805 - val_accuracy: 0.9445
# Epoch 185/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.4522 - val_accuracy: 0.9022
# Epoch 186/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0056 - accuracy: 0.9972 - val_loss: 0.9402 - val_accuracy: 0.8396
# Epoch 187/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.6699 - val_accuracy: 0.8792
# Epoch 188/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0075 - accuracy: 0.9966 - val_loss: 0.3391 - val_accuracy: 0.9299
# Epoch 189/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0041 - accuracy: 0.9981 - val_loss: 0.5810 - val_accuracy: 0.8906
# Epoch 190/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0055 - accuracy: 0.9974 - val_loss: 0.2399 - val_accuracy: 0.9476
# Epoch 191/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 1.2699 - val_accuracy: 0.8005
# Epoch 192/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 0.4055 - val_accuracy: 0.9162
# Epoch 193/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.5854 - val_accuracy: 0.8821
# Epoch 194/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.7097 - val_accuracy: 0.8489
# Epoch 195/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.4563 - val_accuracy: 0.9055
# Epoch 196/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0043 - accuracy: 0.9978 - val_loss: 0.4498 - val_accuracy: 0.9143
# Epoch 197/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0067 - accuracy: 0.9974 - val_loss: 0.9413 - val_accuracy: 0.8340
# Epoch 198/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.3327 - val_accuracy: 0.9266
# Epoch 199/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0052 - accuracy: 0.9973 - val_loss: 0.3049 - val_accuracy: 0.9336
# Epoch 200/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0070 - accuracy: 0.9971 - val_loss: 0.4771 - val_accuracy: 0.8987
# Epoch 201/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0049 - accuracy: 0.9977 - val_loss: 0.3047 - val_accuracy: 0.9315
# Epoch 202/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.4347 - val_accuracy: 0.9166
# Epoch 203/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0030 - accuracy: 0.9982 - val_loss: 0.4781 - val_accuracy: 0.8995
# Epoch 204/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.5064 - val_accuracy: 0.9026
# Epoch 205/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 0.2665 - val_accuracy: 0.9423
# Epoch 206/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 0.6402 - val_accuracy: 0.8853
# Epoch 207/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0067 - accuracy: 0.9970 - val_loss: 0.5436 - val_accuracy: 0.9105
# Epoch 208/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0044 - accuracy: 0.9981 - val_loss: 0.3430 - val_accuracy: 0.9239
# Epoch 209/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.4227 - val_accuracy: 0.9086
# Epoch 210/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0102 - accuracy: 0.9957 - val_loss: 0.7293 - val_accuracy: 0.8631
# Epoch 211/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0056 - accuracy: 0.9970 - val_loss: 0.3967 - val_accuracy: 0.9232
# Epoch 212/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0071 - accuracy: 0.9964 - val_loss: 0.8566 - val_accuracy: 0.8541
# Epoch 213/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0085 - accuracy: 0.9964 - val_loss: 0.4145 - val_accuracy: 0.9090
# Epoch 214/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0072 - accuracy: 0.9968 - val_loss: 0.4372 - val_accuracy: 0.9111
# Epoch 215/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 0.5072 - val_accuracy: 0.8961
# Epoch 216/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 0.7104 - val_accuracy: 0.8525
# Epoch 217/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.5804 - val_accuracy: 0.8919
# Epoch 218/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.4097 - val_accuracy: 0.9218
# Epoch 219/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0055 - accuracy: 0.9976 - val_loss: 0.7219 - val_accuracy: 0.8402
# Epoch 220/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0062 - accuracy: 0.9971 - val_loss: 0.4250 - val_accuracy: 0.9307
# Epoch 221/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0079 - accuracy: 0.9968 - val_loss: 0.7164 - val_accuracy: 0.8693
# Epoch 222/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0063 - accuracy: 0.9969 - val_loss: 0.4372 - val_accuracy: 0.9201
# Epoch 223/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.8941 - val_accuracy: 0.8316
# Epoch 224/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0041 - accuracy: 0.9980 - val_loss: 0.5184 - val_accuracy: 0.9131
# Epoch 225/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0042 - accuracy: 0.9981 - val_loss: 0.5024 - val_accuracy: 0.9013
# Epoch 226/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0070 - accuracy: 0.9965 - val_loss: 0.3049 - val_accuracy: 0.9346
# Epoch 227/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0053 - accuracy: 0.9973 - val_loss: 0.7193 - val_accuracy: 0.8707
# Epoch 228/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.4704 - val_accuracy: 0.9079
# Epoch 229/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 1.3332 - val_accuracy: 0.7794
# Epoch 230/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.8284 - val_accuracy: 0.8628
# Epoch 231/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0060 - accuracy: 0.9971 - val_loss: 0.3688 - val_accuracy: 0.9187
# Epoch 232/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0064 - accuracy: 0.9967 - val_loss: 1.0472 - val_accuracy: 0.8329
# Epoch 233/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0063 - accuracy: 0.9971 - val_loss: 0.5351 - val_accuracy: 0.8950
# Epoch 234/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0067 - accuracy: 0.9970 - val_loss: 0.4893 - val_accuracy: 0.8996
# Epoch 235/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.5917 - val_accuracy: 0.8977
# Epoch 236/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.5643 - val_accuracy: 0.9079
# Epoch 237/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.6403 - val_accuracy: 0.8716
# Epoch 238/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0055 - accuracy: 0.9978 - val_loss: 0.5693 - val_accuracy: 0.8909
# Epoch 239/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0045 - accuracy: 0.9978 - val_loss: 0.6968 - val_accuracy: 0.8780
# Epoch 240/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.6003 - val_accuracy: 0.8867
# Epoch 241/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0045 - accuracy: 0.9976 - val_loss: 0.5269 - val_accuracy: 0.8992
# Epoch 242/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0090 - accuracy: 0.9961 - val_loss: 0.9826 - val_accuracy: 0.8226
# Epoch 243/500
# 1007/1007 [==============================] - 5s 4ms/step - loss: 0.0032 - accuracy: 0.9983 - val_loss: 1.1419 - val_accuracy: 0.8357
# Epoch 244/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0056 - accuracy: 0.9971 - val_loss: 0.6340 - val_accuracy: 0.8893
# Epoch 245/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.9975 - val_loss: 0.6394 - val_accuracy: 0.8915
# Epoch 246/500
# 1007/1007 [==============================] - 4s 4ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 1.0103 - val_accuracy: 0.8400
# Epoch 247/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.
500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.7313 - val_accuracy: 0.8872
# Epoch 311/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 0.7093 - val_accuracy: 0.8820
# Epoch 312/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.5841 - val_accuracy: 0.8965
# Epoch 313/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.4495 - val_accuracy: 0.9173
# Epoch 314/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0028 - accuracy: 0.9982 - val_loss: 0.6121 - val_accuracy: 0.8880
# Epoch 315/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.6633 - val_accuracy: 0.8874
# Epoch 316/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0056 - accuracy: 0.9975 - val_loss: 1.1797 - val_accuracy: 0.8059
# Epoch 317/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 1.6112 - val_accuracy: 0.7840
# Epoch 318/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 0.6766 - val_accuracy: 0.8913
# Epoch 319/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.5315 - val_accuracy: 0.8983
# Epoch 320/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0038 - accuracy: 0.9981 - val_loss: 0.7425 - val_accuracy: 0.8777
# Epoch 321/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.6046 - val_accuracy: 0.9055
# Epoch 322/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.4548 - val_accuracy: 0.9239
# Epoch 323/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0043 - accuracy: 0.9979 - val_loss: 1.0709 - val_accuracy: 0.8390
# Epoch 324/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0062 - accuracy: 0.9975 - val_loss: 0.7778 - val_accuracy: 0.8661
# Epoch 325/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.5145 - val_accuracy: 0.8982
# Epoch 326/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0037 - accuracy: 0.9980 - val_loss: 0.4997 - val_accuracy: 0.9081
# Epoch 327/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.4450 - val_accuracy: 0.9194
# Epoch 328/500
# ...
# Epoch 393/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0040 - accuracy: 0.9978 - val_loss: 0.4805 - val_accuracy: 0.9115
# Epoch 394/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0043 - accuracy: 0.9978 - val_loss: 0.4573 - val_accuracy: 0.9331
# Epoch 395/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0046 - accuracy: 0.9978 - val_loss: 0.7346 - val_accuracy: 0.8756
# Epoch 396/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.4544 - val_accuracy: 0.9189
# Epoch 397/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.5435 - val_accuracy: 0.9103
# Epoch 398/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0027 - accuracy: 0.9985 - val_loss: 0.8589 - val_accuracy: 0.8755
# Epoch 399/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0040 - accuracy: 0.9981 - val_loss: 0.4246 - val_accuracy: 0.9256
# Epoch 400/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.4993 - val_accuracy: 0.9162
# Epoch 401/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0034 - accuracy: 0.9978 - val_loss: 0.4654 - val_accuracy: 0.9188
# Epoch 402/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.7052 - val_accuracy: 0.8833
# Epoch 403/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0037 - accuracy: 0.9983 - val_loss: 0.3895 - val_accuracy: 0.9337
# Epoch 404/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0035 - accuracy: 0.9978 - val_loss: 0.5438 - val_accuracy: 0.9207
# Epoch 405/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.4792 - val_accuracy: 0.9198
# Epoch 406/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.6853 - val_accuracy: 0.9013
# Epoch 407/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.
500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0044 - accuracy: 0.9979 - val_loss: 0.4495 - val_accuracy: 0.9225
# Epoch 440/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0027 - accuracy: 0.9986 - val_loss: 0.3471 - val_accuracy: 0.9392
# Epoch 441/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.4644 - val_accuracy: 0.9259
# Epoch 442/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0055 - accuracy: 0.9975 - val_loss: 0.4351 - val_accuracy: 0.9217
# Epoch 443/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0030 - accuracy: 0.9982 - val_loss: 0.3242 - val_accuracy: 0.9424
# Epoch 444/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0042 - accuracy: 0.9977 - val_loss: 0.4379 - val_accuracy: 0.9196
# Epoch 445/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0032 - accuracy: 0.9982 - val_loss: 1.5615 - val_accuracy: 0.7956
# Epoch 446/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0032 - accuracy: 0.9984 - val_loss: 0.3467 - val_accuracy: 0.9338
# Epoch 447/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0055 - accuracy: 0.9972 - val_loss: 0.6232 - val_accuracy: 0.8901
# Epoch 448/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0033 - accuracy: 0.9978 - val_loss: 0.6944 - val_accuracy: 0.8889
# Epoch 449/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0040 - accuracy: 0.9979 - val_loss: 0.9454 - val_accuracy: 0.8756
# Epoch 450/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.5574 - val_accuracy: 0.9024
# Epoch 451/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0041 - accuracy: 0.9980 - val_loss: 0.4842 - val_accuracy: 0.9256
# Epoch 452/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0039 - accuracy: 0.9981 - val_loss: 0.4916 - val_accuracy: 0.9170
# Epoch 453/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0035 - accuracy: 0.9981 - val_loss: 0.5356 - val_accuracy: 0.9132
# Epoch 454/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.5161 - val_accuracy: 0.9147
# Epoch 455/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.4647 - val_accuracy: 0.9182
# Epoch 456/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0038 - accuracy: 0.9978 - val_loss: 0.4977 - val_accuracy: 0.9101
# Epoch 457/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.6038 - val_accuracy: 0.9076
# Epoch 458/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.3825 - val_accuracy: 0.9322
# Epoch 459/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0026 - accuracy: 0.9985 - val_loss: 0.9148 - val_accuracy: 0.8579
# Epoch 460/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.3812 - val_accuracy: 0.9248
# Epoch 461/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0041 - accuracy: 0.9980 - val_loss: 0.3529 - val_accuracy: 0.9258
# Epoch 462/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0030 - accuracy: 0.9986 - val_loss: 0.3789 - val_accuracy: 0.9305
# Epoch 463/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.5303 - val_accuracy: 0.9172
# Epoch 464/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.5179 - val_accuracy: 0.9193
# Epoch 465/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.5473 - val_accuracy: 0.9083
# Epoch 466/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.6117 - val_accuracy: 0.9017
# Epoch 467/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0036 - accuracy: 0.9976 - val_loss: 0.5530 - val_accuracy: 0.9198
# Epoch 468/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.4251 - val_accuracy: 0.9296
# Epoch 469/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0032 - accuracy: 0.9981 - val_loss: 0.2527 - val_accuracy: 0.9558
# Epoch 470/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0036 - accuracy: 0.9979 - val_loss: 0.5591 - val_accuracy: 0.9021
# Epoch 471/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.4442 - val_accuracy: 0.9244
# Epoch 472/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0047 - accuracy: 0.9976 - val_loss: 0.4646 - val_accuracy: 0.9250
# Epoch 473/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0030 - accuracy: 0.9982 - val_loss: 0.5082 - val_accuracy: 0.9237
# Epoch 474/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0029 - accuracy: 0.9984 - val_loss: 0.9959 - val_accuracy: 0.8702
# Epoch 475/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0044 - accuracy: 0.9978 - val_loss: 0.4350 - val_accuracy: 0.9220
# Epoch 476/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0030 - accuracy: 0.9984 - val_loss: 0.6296 - val_accuracy: 0.8895
# Epoch 477/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.5270 - val_accuracy: 0.9172
# Epoch 478/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0035 - accuracy: 0.9983 - val_loss: 0.8905 - val_accuracy: 0.8774
# Epoch 479/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0034 - accuracy: 0.9981 - val_loss: 0.7200 - val_accuracy: 0.8961
# Epoch 480/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.4492 - val_accuracy: 0.9242
# Epoch 481/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0032 - accuracy: 0.9981 - val_loss: 0.4695 - val_accuracy: 0.9178
# Epoch 482/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.3246 - val_accuracy: 0.9438
# Epoch 483/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0049 - accuracy: 0.9975 - val_loss: 0.6841 - val_accuracy: 0.8962
# Epoch 484/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0032 - accuracy: 0.9983 - val_loss: 0.4380 - val_accuracy: 0.9379
# Epoch 485/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.7099 - val_accuracy: 0.8991
# Epoch 486/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0033 - accuracy: 0.9981 - val_loss: 1.5320 - val_accuracy: 0.8234
# Epoch 487/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.3990 - val_accuracy: 0.9348
# Epoch 488/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0044 - accuracy: 0.9977 - val_loss: 1.0698 - val_accuracy: 0.8394
# Epoch 489/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.5451 - val_accuracy: 0.9120
# Epoch 490/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0041 - accuracy: 0.9977 - val_loss: 0.4759 - val_accuracy: 0.9289
# Epoch 491/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.8858 - val_accuracy: 0.8695
# Epoch 492/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.3551 - val_accuracy: 0.9332
# Epoch 493/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.3493 - val_accuracy: 0.9454
# Epoch 494/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.4289 - val_accuracy: 0.9158
# Epoch 495/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0056 - accuracy: 0.9970 - val_loss: 0.5373 - val_accuracy: 0.9116
# Epoch 496/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0039 - accuracy: 0.9980 - val_loss: 0.7066 - val_accuracy: 0.8983
# Epoch 497/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0031 - accuracy: 0.9983 - val_loss: 0.8447 - val_accuracy: 0.8772
# Epoch 498/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0036 - accuracy: 0.9984 - val_loss: 1.1977 - val_accuracy: 0.8299
# Epoch 499/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0037 - accuracy: 0.9980 - val_loss: 0.6594 - val_accuracy: 0.8944
# Epoch 500/500
# 1007/1007 [==============================] - 5s 5ms/step - loss: 0.0034 - accuracy: 0.9981 - val_loss: 1.0243 - val_accuracy: 0.8709

# %%
X_test.reshape(X_test.shape[0], 48,48,1)
y_test_ = to_categorical(y_test)
print(y_test_ .shape)

x_test = X_test.reshape(X_test.shape[0], 48,48,1)

print(x_test .shape)
# Out:
# (4741, 5)
# (4741, 48, 48, 1)

# %% [markdown]
# # **visualize** the train test accuracy and loss plot to check for overfitting

# %%
# evaluate the model


train_acc = model4.evaluate(X_,Y_, verbose=0)
test_acc = model4.evaluate(x_test,y_test_, verbose=0)

# plot loss during training
plt.subplot(211)
plt.title('Loss')
plt.plot(history4.history['loss'], label='train')
plt.plot(history4.history['val_loss'], label='test')
plt.legend()




# plot accuracy during training
plt.subplot(212)
plt.title('Accuracy')
plt.plot(history4.history['accuracy'], label='train')
plt.plot(history4.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# # **Evalaute the model on Test data set**

# %%
#Making prediction
y_pred=model4.predict_classes(x_test)
y_true=np.argmax( y_test_,axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#Defining function for confusion matrix plot
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):

    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    #Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

#print(cm)

    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')


    #Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %% [markdown]
# # **Print the confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
#Plotting the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred)

#Defining the class labels
class_names=[ 'White American','African American' ,'Asian' ,'Indian','Others'] 

# Plotting  confusion matrix
plot_confusion_matrix(y_true, y_pred, classes = class_names, title='Confusion matrix')
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # ***As data is imbalanced so relying on other parameters rather than accuracy . Calculation for Recall, precisiion, f1-score ***

# %%
from sklearn import metrics
classification_report = metrics.classification_report( y_true,y_pred,target_names =class_names )
print(classification_report)
# Out:
#                   precision    recall  f1-score   support
#
#   White American       0.84      0.84      0.84      2022
# African American       0.80      0.85      0.83       902
#            Asian       0.86      0.87      0.87       711
#           Indian       0.69      0.77      0.73       790
#           Others       0.41      0.22      0.28       316
#
#         accuracy                           0.79      4741
#        macro avg       0.72      0.71      0.71      4741
#     weighted avg       0.78      0.79      0.79      4741

# %% [markdown]
# # ***Displaying the ROC curve ***

# %%
y_score = model4.predict( x_test)

from scipy import interp
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
# Learn to predict each class against the other


n_classes = 5 # number of class




# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
plt.figure()
lw = 2 # line_width
plt.plot(fpr[2], tpr[2], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2]) # Drawing Curve according to 2. class 
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Eğrisi')
plt.legend(loc="lower right")
plt.show()

# %%
from itertools import cycle

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Extending the ROC Curve to Multi-Class')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   if __name__ == '__main__':

# %%
model4.save('model4.hdf5')

from keras.models import load_model
race_model = load_model("/content/model4.hdf5")

# %%
import math

y_pred_prob= race_model.predict(x_test)
ethnicity_true = np.argmax(y_test_,axis=1)
ethnicity_pred= y_pred_prob.argmax(axis=-1)

import math
n = 30
random_indices = np.random.permutation(n)
n_cols = 5
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 20))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(X_test[img_idx].reshape(48,48))
    ax.set_title( 'pred_e:{}'.format(int(ethnicity_pred[img_idx])))
    ax.set_xlabel( 'actual_e:{}'.format(int(ethnicity_true[img_idx])))
    ax.set_xticks([])
    ax.set_yticks([])
